# %%
import mysql.connector as connector

# %%
connection = connector.connect(user = 'coursera', password = 'Coursera10@', database = 'littlelemondb')

# %%
cursor = connection.cursor()

# %%
connection.database
# Out:
# 'littlelemondb'

# %%
show_tables_query = "SHOW TABLES"
cursor.execute(show_tables_query)

# %%
results = cursor.fetchall()
print(results)
# Out:
# [('bookings',), ('customers',), ('employees',), ('menu',), ('menuitems',), ('orderdeliverystatus',), ('orders',), ('ordersview',)]

# %%
join_query ="""SELECT C.CustomersName AS 'Full Name', C.CustomersContact AS 'Client Contact', O.TotalCost AS 'Total Cost' FROM Customers AS C INNER JOIN Orders AS O ON C.CustomerID = O.CustomerID WHERE O.TotalCost > 60;"""

# %%
cursor.execute(join_query)
results = cursor.fetchall()
print(cursor.column_names)
for row in results:
    print(row)
# Out:
# ('Full Name', 'Client Contact', 'Total Cost')
